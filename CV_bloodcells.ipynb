# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_source = cv2.imread('orig_pic.png')
img = cv2.cvtColor(img_source,cv2.COLOR_BGR2GRAY)
img = cv2.GaussianBlur(img,(25,25),0)

# %%
circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,45,
                            param1=50,param2=20,minRadius=23,maxRadius=47)

# %%
cimg = img.copy()
circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

# %%
cv2.imwrite('res_pic.png',cimg)
plt.imshow(cimg)
# Найдено клеток:
circles[0].shape
# Out:
# (40, 3)
